# %%
# !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/JustAnotherArchivist/snscrape.git
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-ye3qi2op
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-ye3qi2op
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 786815dd05681e2421cd03aa9acf5ab5c773bce9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from snscrape==0.6.2.20230321.dev13+g786815d) (2.27.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from snscrape==0.6.2.20230321.dev13+g786815d) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from snscrape==0.6.2.20230321.dev13+g786815d) (4.11.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from snscrape==0.6.2.20230321.dev13+g786815d) (3.12.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->snscrape==0.6.2.20230321.dev13+g786815d) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.6.2.20230321.dev13+g786815d) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.6.2.20230321.dev13+g786815d) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.6.2.20230321.dev13+g786815d) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.6.2.20230321.dev13+g786815d) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.6.2.20230321.dev13+g786815d) (1.7.1)
# Building wheels for collected packages: snscrape
#   Building wheel for snscrape (pyproject.toml) ... done
#   Created wheel for snscrape: filename=snscrape-0.6.2.20230321.dev13+g786815d-py3-none-any.whl size=73302 sha256=5eec90ac3198eba649b77eb13d805364dae59ee83179e0d3d87f2a1feb018ff0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2xpqrt_d/wheels/05/e9/f7/57056e7c7e44b1feed932fa49fdec9d706c4f563e37160ab74
# Successfully built snscrape
# Installing collected packages: snscrape
# Successfully installed snscrape-0.6.2.20230321.dev13+g786815d

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = "anime until:2024-01-01 since:2018-01-01"
tweets = []
limit = 50


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])
        
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])

print(df)
# Out:
# <ipython-input-2-46fddc93c2dd>:16: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-2-46fddc93c2dd>:16: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1651788678270967810-28023361f9491441'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1632038970887372802-28022e655889599b'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1659212341165031424-2802fc9686f46008'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1659212341165031424-28028738a600fc1e'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1658882068200161280-280276c8777f3dea'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1599815537281974273-2802b49259caba71'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1632038970887372802-280251938da50eac'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1659212341165031424-28028f9c234f0f09'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1658882068200161280-2802ec9be405abf3'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1659212341165031424-280249e8386944a0'
#                         Date             User  \
# 0  2023-05-24 23:08:31+00:00        sergygc98
# 1  2023-05-24 23:08:31+00:00      realoakmama
# 2  2023-05-24 23:08:29+00:00         Jimismen
# 3  2023-05-24 23:08:28+00:00  H1Q1ZaX4MLExHml
# 4  2023-05-24 23:08:28+00:00         Goj0sBae
# 5  2023-05-24 23:08:28+00:00       lnrd_modok
# 2   Necesito a alguien con quien comentar el anime...
# 3              @shion_anime おはようございます🥰\n本日も宜しくお願いします🥳
# 4   OMG OMG OMG OMG OMG OMG OMG\n https://t.co/hjS...
# 5   @batbatkkkkk Se o anime fosse só uma adaptação...
# 6   @JiswaPROJECT @LoveRetroBTW The only cheat cod...
# 7   @fallendisguise @LightOfSolaris1 So it’s still...
# 8       @Stanniswasright @GeesusTheWhite @Polygon Yes
# 9   @mojo500jomo @NE0Ndemon There’s always more fo...
# 10  @chaoticmeower American moment, without being ...
# 11  @CarlaOnyx Manga is amazing, anime not so much...
# 12  coisas inúteis sobre mim:\nnome —  Pedro Henri...
# 13                                   @gazya_anime おはよ
# 14  @silverfang09 Whataboutism, you're what's wron...
# 15                        @anime_game_ni おはようございます〜！💪
# 16  Confira o novo visual para do filme do diretor...
# 17                       おはよう https://t.co/MzsGnTpfgk
# 18                   スマホいきなり熱くなってめっちゃくちゃ充電を持っていかれたんだが
# 19  Well great. More Netflix-exclusive anime are g...
# 20                 @ChristinaMarieK Damn right she is
# 21  This probably doesn't count cause it's anime a...
# 22                     @anime_game_ni ヘッドさん、おはようございます
# 23  佐賀競馬マスコットキャラクター「さがのうまこ」がCGアバター化。キャスト：小清水亜美 htt...
# 24                                @yukisiro_litera あ！
# 25  @Am4n0_ Si l'anime de l'année c'est pas celui ...
# 26  nunca vou superar q o anime de VS converteu as...
# 27  @IG5_irving @humberto880 @Aletsp3c Gracias a D...
# 28  E muito anime pra assistir, eu que não vou fic...
# 29  I appreciate and love my anime mutuals on here...
# 30  @Gosenzou_anime せんぞおっはよよよよよよ！！！\nもくもく木曜日(便乗定期)...
# 31  me he acabado el anime de blue lock- flipando ...
# 32  🔴Sinning LIVE\nJoin your father and repent 🙏🏽\...
# 33  setup for today 💕 #gaming #desk #desksetup #ki...
# 34  @sarahchibiP Dura siim! Meus primeiros adesivo...
# 35  @opdubnetflix Se tiver um anime que começa com...
# 36  @alpen10000 @himiyuri_zemi Shimajiro is the pe...
# 37             @whosmythic @MarathonTheGame Anime pfp
# 38  @SweatyyAdriana @helluvqueen The book say she ...
# 39  @deezuus i just did this and i dont even know ...
# 40  Preciso voltar a ver one piece antes do gear 5...
# 41                @chalopus THE OLD MANNNNN YAOIIIIII
# 42                       @acht_anime アハトさん、おはようございます。
# 43   @daphodoodle @AnimeRiverside Omg hi neighbor LOL
# 44        @shoujocrave Omg so cute what anime is this
# 45  @IIkrrrrrr mas vc tá muito longe https://t.co/...
# 46                                                 👈👇
# 47                        Hacer la tarea o ver anime😥
# 48                                  @Nakka_anime おはよう
# 49                         @frost__ost Pinkie: lovely

# %%
df.to_csv('out.csv', index=False)
